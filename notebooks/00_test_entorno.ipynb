# %% [markdown]
# Celda 1 — importar librerías:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
print("Todo OK")
# Out:
# Todo OK

# %% [markdown]
# Celda 2 — versiones:

# %%
print("pandas:", pd.__version__)
print("seaborn:", sns.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# pandas: 2.3.3
# seaborn: 0.13.2
# sklearn: 1.7.2

# %% [markdown]
# Celda 3 — gráfico de prueba:

# %%
sns.set_theme()
datos_prueba = pd.DataFrame({"x": [1,2,3,4,5], "y": [3,1,4,1,5]})
sns.lineplot(data=datos_prueba, x="x", y="y")
plt.title("Gráfico de prueba")
plt.show()
