# %% [markdown]
# # Trayectorias Educativas en Argentina
# ## Carga inicial de datasets
#
# **Autor:** Federico Oscar Giglio
# **Fecha de inicio:** 09/03/2026
# **Última actualización:** 09/04/2026
# **Fuente de datos:** Ministerio de Educación de la Nación — Relevamiento Anual
#
# ### ¿Qué hace este notebook?
# Carga y hace una primera inspección de todos los datasets del proyecto:
# - Base 2: Matrícula y secciones por escuela (2024)
# - Base 3: Trayectoria escolar — promovidos, no promovidos, abandonos (2024)
# - Base 5: Características del establecimiento (2024)
# - Matrícula agregada por departamento (2022–2024) — contexto histórico
# - Tasas de abandono interanual (2003–2024) — contexto histórico
#
# Este notebook corresponde a la **Semana 1–2** del proyecto. El objetivo es confirmar
# que todos los datos cargan correctamente y entender su estructura antes de limpiarlos.

# %% [markdown]
# ## 1. Imports y configuración
#
# Librerías utilizadas en este notebook:
# - `pandas`: manipulación y análisis de datos en tablas
# - `os`: interacción con el sistema de archivos (verificar que los archivos existen)

# %%
import pandas as pd
import os

# %% [markdown]
# ## 2. Carga de datos — Matrícula escolar
#
# Fuente: Ministerio de Educación de la Nación
# Archivos: matrícula total y matrícula por edad, años 2022–2024
# Formato: CSV con separador `;` y encoding `latin-1`
# Ubicación: `data/raw/2022_relevamiento/`, `2023_relevamiento/`, `2024_relevamiento/`
#
# > **Rol en el proyecto:** datos de contexto histórico para análisis de tendencia.
# > La fuente principal del modelo ML es la Base por Escuela 2024 (sección 5).

# %%
# Matrícula total por departamento — 2022, 2023, 2024 (contexto histórico)
df_mat_2022 = pd.read_csv("../data/raw/2022_relevamiento/2022 Matricula - agregada(in).csv", sep=";", encoding="latin-1")
df_mat_2023 = pd.read_csv("../data/raw/2023_relevamiento/2023 Matricula - agregada(in).csv", sep=";", encoding="latin-1")
df_mat_2024 = pd.read_csv("../data/raw/2024_relevamiento/2024 Matricula - agregada(in).csv", sep=";", encoding="latin-1")

# Matrícula por edad — 2022, 2023, 2024 (contexto histórico)
df_edad_2022 = pd.read_csv("../data/raw/2022_relevamiento/2022 Matricula por edad - agregada(in).csv", sep=";", encoding="latin-1")
df_edad_2023 = pd.read_csv("../data/raw/2023_relevamiento/2023 Matricula por edad - agregada(in).csv", sep=";", encoding="latin-1")
df_edad_2024 = pd.read_csv("../data/raw/2024_relevamiento/2024 Matricula por edad - agregada(in).csv", sep=";", encoding="latin-1")

print("=== MATRÍCULA TOTAL ===")
print("2022:", df_mat_2022.shape)
print("2023:", df_mat_2023.shape)
print("2024:", df_mat_2024.shape)

print("\n=== MATRÍCULA POR EDAD ===")
print("2022:", df_edad_2022.shape)
print("2023:", df_edad_2023.shape)
print("2024:", df_edad_2024.shape)
# Out:
# === MATRÍCULA TOTAL ===
# 2022: (1212, 99)
# 2023: (1211, 103)
# 2024: (1216, 104)
#
# === MATRÍCULA POR EDAD ===
# 2022: (20359, 43)
# 2023: (20445, 43)
# 2024: (21389, 43)

# %% [markdown]
# ## 3. Carga de datos — Abandono interanual
#
# Fuente: Ministerio de Educación de la Nación
# Archivos: tasas de abandono interanual, dos series históricas
# - `2024-2012`: serie reciente por división político-territorial
# - `2016-2003`: serie histórica con estructura nacional homogénea
#
# Ubicación: `data/raw/abandono_historico/`
#
# **Nota técnica:** los archivos Excel tienen encabezado institucional en las primeras 10 filas.
# Se usa `skiprows=10` para saltar esas filas y leer directamente los datos.

# %%
abandono_reciente = pd.read_excel(
    "../data/raw/abandono_historico/Tasa de Abandono Interanual 2024-2012 según división político-territorial.xlsx",
    skiprows=10
)

abandono_historico = pd.read_excel(
    "../data/raw/abandono_historico/Tasa de Abandono Interanual 2016-2003 según estructura nacional homogenea.xlsx",
    skiprows=10
)

print("Reciente:", abandono_reciente.shape)
print("Histórico:", abandono_historico.shape)
abandono_reciente.head(5)
# Out:
# Reciente: (38, 17)
# Histórico: (36, 17)
#                                           Unnamed: 0 Unnamed: 1     Total  \
# 0                                         Total País        NaN  0.516238
# 1  Buenos Aires                                  ...        6-6  0.405685
# 2              Conurbano                                    6-6  0.589701
# 3  Resto de Bs As                                           6-6  0.109314
# 4  Catamarca                                     ...        6-6 -0.134867
#
#      1° Año    2° Año    3° Año    4° Año    5° Año    6° Año    7° Año  \
# 0 -0.147195  0.919616  0.882836  0.629229  0.778037  0.071039  0.236353
# 1 -0.691481  1.179272  0.894652  0.508399  0.661824 -0.232935       NaN
# 2 -0.547618   1.42583  1.210142  0.691566  0.832068 -0.202899       NaN
# 3 -0.918872  0.783844  0.384918  0.212823  0.385332 -0.281698       NaN
# 4 -0.851125 -0.906516  0.421163 -0.496736  0.605971  0.408044       NaN
#
# ...

# %% [markdown]
# ## 4. Vista rápida de los datos
#
# Primera inspección de estructura y calidad de cada dataset.
# Verificamos: cantidad de filas/columnas, tipos de datos, valores nulos.

# %%
# --- MATRÍCULA TOTAL ---
print("=== MATRÍCULA TOTAL 2024 ===")
print(df_mat_2024.info())

# --- MATRÍCULA POR EDAD ---
print("\n=== MATRÍCULA POR EDAD 2024 ===")
print(df_edad_2024.info())

# --- ABANDONO RECIENTE ---
print("\n=== ABANDONO INTERANUAL 2012-2024 ===")
print(abandono_reciente.info())

# --- ABANDONO HISTÓRICO ---
print("\n=== ABANDONO INTERANUAL 2003-2016 ===")
print(abandono_historico.info())

# --- BASES RELEVAMIENTO ANUAL 2024 ---
print("\n=== BASE 2 — MATRÍCULA POR ESCUELA ===")
print(df_base2.info())

print("\n=== BASE 3 — TRAYECTORIA POR ESCUELA ===")
print(df_base3.info())

print("\n=== BASE 5 — CARACTERÍSTICAS DEL ESTABLECIMIENTO ===")
print(df_base5.info())
# Out:
# === MATRÍCULA TOTAL 2024 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216 entries, 0 to 1215
# Columns: 104 entries, provincia to multinivel
# dtypes: int64(24), object(80)
# memory usage: 988.1+ KB
# None
#
# === MATRÍCULA POR EDAD 2024 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21389 entries, 0 to 21388
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   provincia      21389 non-null  object
#  1   Departamento   21389 non-null  object
#  2   sector         21389 non-null  object
#  3   ambito         21389 non-null  object
#  4   grado          21389 non-null  object
#  5   0años          21389 non-null  int64
#  6   1año           21389 non-null  int64
#  7   2años          21389 non-null  int64
#  8   3años          21389 non-null  int64
#  9   4años          21389 non-null  int64
#  10  5años          21389 non-null  int64
#  11  6años          21389 non-null  int64
# ...

# %% [markdown]
# ## 5. Carga de datos — Relevamiento Anual 2024 (fuente principal)
#
# Fuente: Ministerio de Educación de la Nación — Base por Escuela 2024
# Archivos: Base 2 (matrícula), Base 3 (trayectoria), Base 5 (características)
# Ubicación: `data/raw/2024_relevamiento/`
#
# Estas tres bases tienen **una fila por escuela**, a diferencia de los datasets
# anteriores que están agregados por departamento. Son el núcleo del proyecto.

# %%
# Base 2 — Matrícula y secciones por escuela
df_base2 = pd.read_csv(
    "../data/raw/2024_relevamiento/2024 Matricula - agregada(in).csv",
    sep=";", encoding="latin-1"
)

# Base 3 — Trayectoria: promovidos, no promovidos, salidos con/sin pase
df_base3 = pd.read_csv(
    "../data/raw/2024_relevamiento/2024 Trayectoria - agregada(in).csv",
    sep=";", encoding="latin-1"
)

# Base 5 — Características del establecimiento
df_base5 = pd.read_csv(
    "../data/raw/2024_relevamiento/2024 Caracteristicas - agregada(in).csv",
    sep=";", encoding="latin-1"
)

print("=== BASES RELEVAMIENTO ANUAL 2024 ===")
print("Base 2 - Matrícula:", df_base2.shape)
print("Base 3 - Trayectoria:", df_base3.shape)
print("Base 5 - Características:", df_base5.shape)

print("\n--- Columnas Base 3 (Trayectoria) ---")
print(df_base3.columns.tolist())
# Out:
# === BASES RELEVAMIENTO ANUAL 2024 ===
# Base 2 - Matrícula: (1216, 104)
# Base 3 - Trayectoria: (1209, 288)
# Base 5 - Características: (1216, 66)
#
# --- Columnas Base 3 (Trayectoria) ---
# ...
